# %%
import matplotlib.pyplot as plt

# %%
days =      [1,2,3,4,5]
sleeping =  [6,7,8,11,7]
eating =    [2,3,4,3,2]
working =   [7,8,7,2,2,]
playing =   [8,5,7,8,13]

# %%
plt.plot([],[],color='m',label='sleeping',linewidth=5)
plt.plot([],[],color='c',label='eating',linewidth=5)
plt.plot([],[],color='r',label='working',linewidth=5)
plt.plot([],[],color='k',label='playing',linewidth=5)

# %%
# plt.stackplot(days,sleeping,eating,working,playing, colors=['red','blue','black','orange'])

plt.stackplot(days,sleeping,eating,working,playing, colors=['m','c','r','k'])
# Out:
# [<matplotlib.collections.PolyCollection at 0x116683f3dd8>,
#  <matplotlib.collections.PolyCollection at 0x116687b97f0>,
#  <matplotlib.collections.PolyCollection at 0x116687b9f28>,
#  <matplotlib.collections.PolyCollection at 0x116687c66a0>]

# %%
plt.xlabel('x')
plt.ylabel('y')
plt.title('Intresting topic')
plt.legend()
plt.show()
