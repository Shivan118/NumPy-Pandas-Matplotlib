# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\ProgramData\Ml_Data\Topic_Survey_Assignment.csv")

# %%
data.head(5)
# Out:
#                    Unnamed: 0  Very interested  Somewhat interested  \
# 0   Big Data (Spark / Hadoop)             1332                  729
# 1  Data Analysis / Statistics             1688                  444
# 2             Data Journalism              429                 1081
# 3          Data Visualization             1340                  734
# 4               Deep Learning             1263                  770
#
#    Not interested
# 0             127
# 1              60
# 2             610
# 3             102
# 4             136

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
# Unnamed: 0             6 non-null object
# Very interested        6 non-null int64
# Somewhat interested    6 non-null int64
# Not interested         6 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 272.0+ bytes

# %%
data.columns.values
# Out:
# array(['Unnamed: 0', 'Very interested', 'Somewhat interested',
#        'Not interested'], dtype=object)

# %%
data.index.values
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=int64)

# %%
data.shape
# Out:
# (6, 4)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0             0
# Very interested        0
# Somewhat interested    0
# Not interested         0
# dtype: int64

# %%
# data.describe()

# %%
data.plot("Very interested",kind='Bar')

plt.title('intrest in data science area')


plt.show()

# %%
data = pd.read_csv(r"C:\ProgramData\Ml_Data\Police_Department_Incidents_-_Previous_Year__2016_.csv")

# %%
data
# Out:
#         IncidntNum         Category  \
# 0        120058272      WEAPON LAWS
# 1        120058272      WEAPON LAWS
# 2        141059263         WARRANTS
# 3        160013662     NON-CRIMINAL
# 4        160002740     NON-CRIMINAL
# 5        160002869          ASSAULT
# 6        160003130   OTHER OFFENSES
# 7        160003259     NON-CRIMINAL
# 8        160003970         WARRANTS
# 9        160003641   MISSING PERSON
# 10       160086863    LARCENY/THEFT
# 11       160004053     NON-CRIMINAL
# 12       160073014   OTHER OFFENSES
# 13       140776777          ASSAULT
# 14       160004069         BURGLARY
# 15       160004150  STOLEN PROPERTY
# 16       160004241          ROBBERY
# 17       160004558          ASSAULT
# 18       160004655          ASSAULT
# 19       160004837    LARCENY/THEFT
# 20       160005421            FRAUD
# 21       160005750         WARRANTS
# 22       160005841    DRUG/NARCOTIC
# 23       160005841   OTHER OFFENSES
# 24       160006071          ASSAULT
# ...
